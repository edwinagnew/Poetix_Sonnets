# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np

# %% [markdown]
# ## 28/07

# %%
model_size = [2,2,1,4,4,1,3,1,3,4,3,2,1,3,2,4,2,4,2,4,3,1,2,2]
edwin_scores = [3.0, 4.0, 3.5, 2.5, 3.5, 3.0, 3.0, 3.5, 2.5, 4.5, 3.0, 3.0, 3.5, 2.0, 3.0, 3.5, 3.5, 2.5, 3.0, 3.5, 3.0, 3.0, 3.0, 2.5]
ben_scores = [3.0, 3.5, 3.0, 2.0, 2.5, 3.0, 4.0, 2.5, 2.5, 4.5, 2.5, 3.0, 3.5, 3.5, 3.0, 2.5, 2.5, 3.5, 2.0, 3.5, 3.0, 2.0, 2.5, 2.0]
#kari_scores = []
jordan_scores = [3.0, 3.5, 3.5, 3.0, 3.0, 2.0, 4.0, 2.0, 2.5, 4.0, 3.0, 2.5, 3.0, 2.5, 3.0, 2.5, 2.5, 3.0, 2.0, 3.0, 3.0, 2.5, 2.5, 3.0]

# %%
x = model_size
y = edwin_scores
m, b = np.polyfit(np.array(x), np.array(y), 1)
print(np.corrcoef(x,y))

plt.scatter(x, y)
plt.plot(x, m*np.array(x) + b)
plt.title("edwin")
plt.ylabel("edwin scores")
plt.xlabel("GPT model size")
# Out:
# [[ 1.         -0.03671115]
#  [-0.03671115  1.        ]]
# Text(0.5, 0, 'GPT model size')

# %%
x = model_size
y = ben_scores
m, b = np.polyfit(np.array(x), np.array(y), 1)
print(np.corrcoef(x,y))

plt.scatter(x, y)
plt.plot(x, m*np.array(x) + b)
plt.title("ben")
plt.ylabel("ben scores")
plt.xlabel("GPT model size")
# Out:
# [[1.         0.22422218]
#  [0.22422218 1.        ]]
# Text(0.5, 0, 'GPT model size')

# %%
x = model_size
y = jordan_scores
m, b = np.polyfit(np.array(x), np.array(y), 1)
print(np.corrcoef(x,y))

plt.scatter(x, y)
plt.plot(x, m*np.array(x) + b)
plt.title("jordan")
plt.ylabel("jordan scores")
plt.xlabel("GPT model size")
# Out:
# [[1.         0.34577857]
#  [0.34577857 1.        ]]
# Text(0.5, 0, 'GPT model size')

# %%
y = mean_scores = [3.0, 3.6666666666666665, 3.3333333333333335, 2.5, 3.0, 2.6666666666666665, 3.6666666666666665, 2.6666666666666665, 2.5, 4.333333333333333, 2.8333333333333335, 2.8333333333333335, 3.3333333333333335, 2.6666666666666665, 3.0, 2.8333333333333335, 2.8333333333333335, 3.0, 2.3333333333333335, 3.3333333333333335, 3.0, 2.5, 2.6666666666666665, 2.5]
x = model_size

m, b = np.polyfit(np.array(x), np.array(y), 1)
print(np.corrcoef(x,y))

plt.scatter(x, y)
plt.plot(x, m*np.array(x) + b)
plt.title("mean")
plt.ylabel("mean scores")
plt.xlabel("GPT model size")
# Out:
# [[1.         0.22631944]
#  [0.22631944 1.        ]]
# Text(0.5, 0, 'GPT model size')

# %%
x = [0, 5, 10]
y = [-0.0178571428571436, 0.13392857142857093, 0.16964285714285668]

m, b = np.polyfit(np.array(x), np.array(y), 1)
print(np.corrcoef(x,y))

plt.scatter(x, y)
plt.plot(x, m*np.array(x) + b)
plt.title("expertise")
plt.ylabel("prediction fit")
plt.xlabel("(expected) number of Duke English classes")
# Out:
# [[1.         0.94166301]
#  [0.94166301 1.        ]]
# Text(0.5, 0, '(expected) number of Duke English classes')

# %%
y = gpt_scores = [5.44690465927124, 5.427978515625, 5.75692081451416, 4.981895446777344, 5.175206661224365, 5.863924503326416, 5.256760120391846, 5.259716987609863, 5.511695861816406, 5.453114032745361, 5.051534175872803, 4.718928337097168, 5.412407398223877, 4.828188419342041, 5.710199356079102, 5.423792362213135, 5.273957252502441, 5.247771263122559, 4.7999796867370605, 5.179005146026611, 5.3674468994140625, 6.008047580718994, 5.825976371765137, 4.629999160766602]
x = model_size

m, b = np.polyfit(np.array(x), np.array(y), 1)
print(np.corrcoef(x,y))

plt.scatter(x, y)
plt.plot(x, m*np.array(x) + b)
plt.title("GPT score")
plt.ylabel("GPT score")
plt.xlabel("GPT model size")
# Out:
# [[ 1.         -0.34219424]
#  [-0.34219424  1.        ]]
# Text(0.5, 0, 'GPT model size')

# %% [markdown]
# ## 07/07

# %% [markdown]
# ## 1 random - 3 gpt

# %%
data = open("../saved_objects/local_generated_stanzas/1rand_3g.txt").read()
data.split("1,3,")
# Out:
# ['',
#  "And fold her loo deep when she swipes abreast.\nAvoid's beneath is spreading but is bare,\nto tell within her soft warm welcome Furthermore,\nnot sealed the garden's sanctuary Bear.,6.376408100128174,[5.683874130249023, 7.162841320037842, 8.082852363586426, 8.277823448181152]\n",
#  'Quite doth the scrip that should be another,\nbe subtle, and his purpose is with him.\nWas an all other whale and manyelman.\nOft in a fat beauty could he be nonpartisan.,5.872162342071533,[5.2428460121154785, 4.775908470153809, 7.925300121307373, 7.2506537437438965]\n',
#  'Warm lovely, and her wager taunts with her.\nForgetting nothing with herself again,\nwhen other courses shall prevail her Sir,\nproving good, she is to those that are w.,5.486067771911621,[5.916225910186768, 6.971445083618164, 8.008689880371094, 5.305502891540527]\n',
# ...

# %%
data.split("1,3,")[1].split("[")[1].split("]")[0].split(",")
# Out:
# ['5.683874130249023',
#  ' 7.162841320037842',
#  ' 8.082852363586426',
#  ' 8.277823448181152']

# %%
scores = [[float(y) for y in x.split("[")[1].split("]")[0].split(",")] for x in data.split("1,3,")[1:]]
scores
# Out:
# [[5.683874130249023, 7.162841320037842, 8.082852363586426, 8.277823448181152],
#  [5.2428460121154785,
#   4.775908470153809,
#   7.925300121307373,
#   7.2506537437438965],
#  [5.916225910186768, 6.971445083618164, 8.008689880371094, 5.305502891540527],
#  [5.2250590324401855,
#   4.946722507476807,
#   7.770927906036377,
#   6.3298115730285645],
#  [5.517752647399902, 6.952641010284424, 8.805978775024414, 8.24811840057373],
#  [5.916976451873779, 7.6245880126953125, 6.528351783752441, 7.850342750549316],
#  [5.790561676025391, 6.551308631896973, 6.888670444488525, 8.731912612915039],
#  [5.851617813110352, 6.840631008148193, 7.496264457702637, 6.095277309417725],
#  [5.448153972625732, 5.924227237701416, 6.8314714431762695, 9.27021598815918],
#  [5.737154006958008, 8.942109107971191, 8.551335334777832, 6.712893962860107],
#  [5.539144039154053, 4.647600173950195, 8.130668640136719, 8.431724548339844],
#  [5.837213039398193, 6.533043384552002, 6.171135425567627, 7.775163650512695],
# ...

# %%
plt.title("Score of each line")
plt.xlabel("index")
plt.ylabel("score")
for s in scores:
    plt.plot(s)

# %%
plt.title("mean score of each line")
plt.xlabel("index")
plt.ylabel("score")
for i in range(4):
    plt.scatter(i, np.mean([s[i] for s in scores]))

# %%
(data.split("1,3,")[1].split(".,")[0] + ".").split("\n")
# Out:
# ['And fold her loo deep when she swipes abreast.',
#  "Avoid's beneath is spreading but is bare,",
#  'to tell within her soft warm welcome Furthermore,',
#  "not sealed the garden's sanctuary Bear."]

# %%
first_couplets = []
second_couplets = []
for d in data.split("1,3,")[1:]:
    if ".," in d: 
        lines = d.split(".,")[0] + "."
    elif "?," in d:
        lines = d.split("?,")[0] + "?"
    first_couplets.append(" ".join(lines.split("\n")[:2]))
    second_couplets.append(" ".join(lines.split("\n")[2:]))

# %%
first_couplet_scores = [6.4477620124816895,
 5.140408515930176,
 6.042532444000244,
 5.037655353546143,
 5.72553825378418,
 6.666868209838867,
 5.809024810791016,
 5.911423206329346,
 5.566421985626221,
 6.311217308044434,
 5.129208564758301,
 6.357265472412109,
 5.5376811027526855,
 5.754212379455566,
 6.529473781585693,
 6.321420669555664,
 6.620574951171875,
 5.2568359375,
 6.349661350250244,
 7.130413055419922,
 5.3785247802734375,
 5.886120319366455,
 5.886229515075684,
 5.626558303833008,
 6.391976833343506,
 6.557400226593018,
 5.645214080810547,
 6.192349910736084,
 6.154926300048828,
 4.658272743225098,
 6.2180891036987305,
 5.416345596313477,
 5.498232841491699,
 5.863673686981201,
 5.881115913391113,
 6.072592258453369,
 5.7813520431518555,
 6.19346809387207,
 5.050508499145508,
 5.474376678466797,
 6.642789363861084,
 6.0759053230285645,
 7.090644836425781,
 5.297314643859863,
 5.628043174743652,
 5.854345798492432,
 5.2782769203186035,
 5.436502933502197,
 6.764106750488281,
 5.819991111755371,
 7.004203796386719,
 5.361386299133301,
 6.528730869293213,
 6.591811180114746,
 5.064982891082764,
 5.990946292877197,
 5.328556060791016,
 6.4649200439453125,
 6.276511192321777,
 6.415951728820801,
 6.00734281539917,
 6.665653228759766,
 5.809319496154785,
 5.446766376495361,
 7.042611598968506,
 6.8290696144104,
 5.826664447784424,
 5.867705345153809,
 5.473935127258301,
 5.884806156158447,
 5.230332374572754,
 5.669081211090088,
 5.668687343597412,
 5.722093105316162,
 5.283870220184326,
 6.895169734954834,
 5.393962860107422,
 6.039736270904541,
 5.023034572601318,
 5.837042808532715,
 5.8940629959106445,
 5.189398288726807,
 5.776875019073486,
 6.229406356811523,
 5.7453155517578125,
 5.477776050567627,
 5.989960193634033,
 5.972745895385742,
 5.804027080535889,
 5.970719814300537,
 4.83863639831543,
 6.56093692779541,
 6.443434238433838,
 5.88715934753418,
 6.317486763000488,
 6.1952314376831055,
 5.543043613433838,
 5.457059383392334,
 6.479145526885986,
 6.123976230621338,
 6.285575866699219,
 6.51975679397583]

# %%
len(first_couplet_scores) == len(first_couplets)
# Out:
# True

# %%
second_couplet_scores = [7.718121528625488,
 7.096717357635498,
 6.55623722076416,
 6.721983432769775,
 8.58625316619873,
 6.802455425262451,
 7.742088317871094,
 6.280742168426514,
 7.914228439331055,
 7.312560081481934,
 7.832489013671875,
 6.489088535308838,
 7.617925643920898,
 8.26119613647461,
 6.797645092010498,
 8.223984718322754,
 6.7098588943481445,
 5.837701320648193,
 7.11737060546875,
 7.430384159088135,
 6.942419528961182,
 7.689823150634766,
 7.600359916687012,
 6.711751937866211,
 8.311653137207031,
 7.946077823638916,
 7.287863731384277,
 6.372076034545898,
 6.13277006149292,
 7.615425109863281,
 7.0029826164245605,
 6.344964027404785,
 7.522190570831299,
 8.499107360839844,
 6.718898773193359,
 7.146782875061035,
 7.321461200714111,
 8.463078498840332,
 8.15701961517334,
 6.761341571807861,
 7.728702068328857,
 6.567843914031982,
 5.861527919769287,
 8.162742614746094,
 7.53005838394165,
 6.989746570587158,
 6.765766620635986,
 7.385261535644531,
 6.412951469421387,
 9.116965293884277,
 7.417086601257324,
 7.557242393493652,
 7.970501899719238,
 8.105387687683105,
 4.6787214279174805,
 7.619888782501221,
 5.910955429077148,
 7.57588005065918,
 8.897706031799316,
 6.793465614318848,
 7.167442798614502,
 7.140079021453857,
 6.734487533569336,
 7.504465103149414,
 8.326993942260742,
 6.43071174621582,
 6.081767559051514,
 6.596184730529785,
 6.611288070678711,
 6.024745941162109,
 6.452995777130127,
 7.905206203460693,
 6.66232442855835,
 6.179439067840576,
 6.6531500816345215,
 7.402161121368408,
 6.994540214538574,
 7.291013240814209,
 6.885993957519531,
 6.954809665679932,
 7.27029275894165,
 6.930597305297852,
 7.4224677085876465,
 6.047356605529785,
 8.81986141204834,
 7.793060302734375,
 7.11307430267334,
 7.688296318054199,
 7.529745101928711,
 6.334258079528809,
 5.807080268859863,
 7.461254119873047,
 8.73869800567627,
 7.09980583190918,
 6.112428188323975,
 7.300276756286621,
 7.0589799880981445,
 7.030572891235352,
 6.809571266174316,
 6.50869083404541,
 7.732699871063232,
 8.446688652038574]

# %%
plt.hist(first_couplet_scores, alpha=0.5, label='first two')
plt.hist(second_couplet_scores, alpha=0.5, label='last two')
plt.legend(loc='upper right')

# %% [markdown]
# ## 1 rand 5 gpt

# %%
data = open("../saved_objects/local_generated_stanzas/1rand_5g.txt").read()
data.split("1,5,")
# Out:
# ['',
#  "Die angered, and your sneezing tolls with you.\nIf you could witness this warm air of death,\nhow often more calls needed your look's view.\nProving warm, you is to those that look anchorage.\nSo you through glances of warm arms shall do,\nfor cooling pleasure with yourself alone,,5.311647891998291,[5.2074174880981445, 5.219741344451904, 7.667783260345459, 6.42993688583374, 7.417087078094482, 7.935205459594727]\n",
#  'Resist resumed and butchered every where.\nAgain shall you be as objects befit,\nor who you is so bright to meet the care.\nThe very thought where every thing is fit.\nBut as the castle should by law declare,\nLook is disguised, your busy Life, fair Kathryn;,5.379379749298096,[5.528141021728516, 5.880371570587158, 6.430291652679443, 6.228430271148682, 5.673915863037109, 7.771205902099609]\n',
# ...

# %%
scores = [[float(y) for y in x.split("[")[1].split("]")[0].split(",")] for x in data.split("1,5,")[1:]]
scores
# Out:
# [[5.2074174880981445,
#   5.219741344451904,
#   7.667783260345459,
#   6.42993688583374,
#   7.417087078094482,
#   7.935205459594727],
#  [5.528141021728516,
#   5.880371570587158,
#   6.430291652679443,
#   6.228430271148682,
#   5.673915863037109,
#   7.771205902099609],
#  [5.738823413848877,
#   6.6890106201171875,
#   10.627906799316406,
#   8.162910461425781,
#   11.262763023376465,
#   8.795912742614746],
#  [5.767099380493164,
#   7.820900917053223,
#   6.082927703857422,
#   7.476809024810791,
#   6.086277961730957,
#   6.799027442932129],
#  [4.904428958892822,
#   5.894233226776123,
#   7.038421630859375,
#   5.0834269523620605,
#   5.764913558959961,
#   9.273085594177246],
#  [5.687777996063232,
#   7.30966854095459,
#   8.246332168579102,
#   6.874306678771973,
#   7.727540016174316,
#   6.111641883850098],
#  [5.858604907989502,
#   7.4079718589782715,
#   6.227869987487793,
#   9.311676979064941,
#   7.855348110198975,
#   6.635941028594971],
#  [5.408812046051025,
# ...

# %%
plt.title("Score of each line")
plt.xlabel("index")
plt.ylabel("score")
for s in scores:
    plt.plot(s)

# %%
plt.title("mean score of each line")
plt.xlabel("index")
plt.ylabel("score")
for i in range(6):
    plt.scatter(i, np.mean([s[i] for s in scores]))

# %%
gens = data.split("1,5,")[1:]
[g for g in gens if ",5" in g][0].split(",5")[0].split("\n")[-4:]
# Out:
# ["how often more calls needed your look's view.",
#  'Proving warm, you is to those that look anchorage.',
#  'So you through glances of warm arms shall do,',
#  'for cooling pleasure with yourself alone,']

# %%
last_4 = []
for g in gens:
    for i in [",4", ",5", ",6"]:
        if i in g: last_4.append(" ".join(g.split(i)[0].split("\n")[-4:]))
len(last_4)
# Out:
# 100

# %%
last_4_scores = [6.405590534210205,
 6.171025276184082,
 8.887295722961426,
 6.296632289886475,
 6.3467206954956055,
 6.736346244812012,
 7.035193920135498,
 6.571325302124023,
 6.99627161026001,
 6.50472354888916,
 6.221116065979004,
 8.242082595825195,
 6.919009208679199,
 7.558517932891846,
 6.707300186157227,
 7.577888488769531,
 7.32245397567749,
 7.269223213195801,
 6.987096786499023,
 7.981659889221191,
 7.885224342346191,
 7.724116325378418,
 7.146872520446777,
 7.4776291847229,
 8.1920166015625,
 6.915235996246338,
 6.9691643714904785,
 6.353120803833008,
 6.698714256286621,
 6.589508056640625,
 7.036063194274902,
 8.596731185913086,
 7.641086578369141,
 7.01358699798584,
 7.56197452545166,
 7.779736518859863,
 6.53815221786499,
 7.68418550491333,
 7.0140700340271,
 7.484229564666748,
 6.791135311126709,
 6.381662368774414,
 5.807003498077393,
 6.824917793273926,
 8.082645416259766,
 7.033670902252197,
 6.965725421905518,
 6.320094108581543,
 6.466233730316162,
 7.3712310791015625,
 7.094912052154541,
 8.082815170288086,
 6.745612144470215,
 6.582864761352539,
 6.866423606872559,
 6.451547622680664,
 6.4208173751831055,
 7.049840927124023,
 7.728164196014404,
 6.462454795837402,
 7.763619422912598,
 7.343440055847168,
 6.912624835968018,
 6.25626277923584,
 7.665022373199463,
 7.606738090515137,
 6.456480979919434,
 6.551554203033447,
 7.027468204498291,
 6.682981014251709,
 7.3396315574646,
 6.673712730407715,
 6.903059959411621,
 7.2475199699401855,
 7.1210618019104,
 7.8957343101501465,
 7.481381416320801,
 6.383837699890137,
 5.435307502746582,
 6.3646955490112305,
 7.238332748413086,
 7.145539283752441,
 6.65500020980835,
 6.243542194366455,
 7.157562255859375,
 7.097447872161865,
 5.901981353759766,
 7.005876064300537,
 7.759568691253662,
 8.139182090759277,
 6.849485874176025,
 6.394481658935547,
 6.775266170501709,
 6.9590654373168945,
 6.9985785484313965,
 7.164497375488281,
 7.052020072937012,
 6.400329113006592,
 6.529960632324219,
 7.509951114654541]

# %%
stanzas = []
for g in gens:
    for i in [",4", ",5", ",6"]:
        if i in g: stanzas.append(g.split(i)[0])
print(len(stanzas))
stanzas
# Out:
# 100
# ["Die angered, and your sneezing tolls with you.\nIf you could witness this warm air of death,\nhow often more calls needed your look's view.\nProving warm, you is to those that look anchorage.\nSo you through glances of warm arms shall do,\nfor cooling pleasure with yourself alone,",
#  'Resist resumed and butchered every where.\nAgain shall you be as objects befit,\nor who you is so bright to meet the care.\nThe very thought where every thing is fit.\nBut as the castle should by law declare,\nLook is disguised, your busy Life, fair Kathryn;',
#  'Which tattered pygmy envelopes to flit?\nThe very thought where every star is wound,\nforhaving winding with herself advertise,\nand coloured scar is wound in Schmidt.\nPerfect preserves would probablyete\nthe Southern Britain naked her to get',
# ...

# %%
total_scores = [float(g.split(",[")[0].split(",")[-1]) for g in gens]
total_scores
# Out:
# [5.311647891998291,
#  5.379379749298096,
#  6.7455573081970215,
#  5.865286350250244,
#  5.152501106262207,
#  5.824191093444824,
#  5.850500106811523,
#  5.678071975708008,
#  6.094372749328613,
#  5.960620880126953,
#  5.3297295570373535,
#  6.538132190704346,
#  5.755442142486572,
#  6.262417793273926,
#  5.478170394897461,
#  6.512465953826904,
#  6.0960893630981445,
#  5.896729469299316,
#  5.929909706115723,
#  6.161094665527344,
#  6.119515895843506,
#  6.22099494934082,
#  6.038885593414307,
#  6.027532577514648,
#  6.378674030303955,
#  6.393580436706543,
#  6.079517364501953,
#  5.690310001373291,
#  5.874096393585205,
#  5.371822357177734,
#  5.83059024810791,
#  6.466367244720459,
#  6.547631740570068,
#  5.673445701599121,
#  6.359195709228516,
#  6.39987850189209,
#  5.615901947021484,
#  5.734803199768066,
#  5.977445125579834,
#  6.265985488891602,
#  5.71605920791626,
#  5.220904350280762,
#  5.509511470794678,
#  5.943816184997559,
#  6.547730445861816,
# ...

# %%
gens[4].split(",[")[-1].strip("]\n").split(",")
# Out:
# ['4.904428958892822',
#  ' 5.894233226776123',
#  ' 7.038421630859375',
#  ' 5.0834269523620605',
#  ' 5.764913558959961',
#  ' 9.273085594177246']

# %%
means = [[float(y) for y in g.split(",[")[-1].strip("]\n").split(",")] for g in gens]
means = [np.mean(x) for x in means]
means
# Out:
# [6.646195252736409,
#  6.25205938021342,
#  8.546221176783243,
#  6.672173738479614,
#  6.326418320337932,
#  6.992877880732219,
#  7.216235478719075,
#  7.853271722793579,
#  7.256327072779338,
#  7.7453828652699785,
#  6.576207399368286,
#  8.337853272755941,
#  6.965073744455974,
#  7.381810983022054,
#  6.657343149185181,
#  7.30691385269165,
#  8.003705898920694,
#  7.513864278793335,
#  6.90521772702535,
#  7.192038297653198,
#  7.906327486038208,
#  7.81588339805603,
#  7.545164267222087,
#  8.422481695810953,
#  7.67565393447876,
#  7.518483400344849,
#  6.998955647150676,
#  6.783366044362386,
#  8.279797951380411,
#  6.730955282847087,
#  7.118093808492024,
#  8.410166343053183,
#  8.006385882695517,
#  6.83443546295166,
#  7.676787694295247,
#  7.740485668182373,
#  6.911846558252971,
#  7.802717447280884,
#  7.005276362101237,
#  7.86387316385905,
#  7.201509396235148,
#  6.66391126314799,
#  7.360699574152629,
#  6.874494711558024,
#  8.130675872166952,
# ...

# %%
plt.scatter(total_scores, means)
plt.xlabel("total score")
plt.ylabel("mean score of all lines")
xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)

# %%
np.corrcoef(total_scores, means)
# Out:
# array([[1.        , 0.69214387],
#        [0.69214387, 1.        ]])

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

x = total_scores #x is whole
y = last_4_scores #y is last line
names = stanzas
c = means #c is first line

#norm = plt.Normalize(1,4)
cmap = plt.cm.RdYlGn

fig,ax = plt.subplots()
sc = plt.scatter(x,y,c=c, s=100, cmap=cmap)#, norm=norm)
plt.xlabel('all lines')
plt.ylabel('last 4')
annot = ax.annotate("", xy=(0,0), xytext=(20,20),textcoords="offset points",
                    bbox=dict(boxstyle="round", fc="w"),
                    arrowprops=dict(arrowstyle="->"))
annot.set_visible(False)

def update_annot(ind):

    pos = sc.get_offsets()[ind["ind"][0]]
    print(pos)
    print(sc.get_offsets())
    annot.xy = pos
    text = "{}".format(" ".join([names[n] for n in ind["ind"]]))
    annot.set_text(text)
    annot.get_bbox_patch().set_facecolor(cmap(c[ind["ind"][0]]))
    annot.get_bbox_patch().set_alpha(1)


def hover(event):
    vis = annot.get_visible()
    if event.inaxes == ax:
        cont, ind = sc.contains(event)
        if cont:
            update_annot(ind)
            annot.set_visible(True)
            fig.canvas.draw_idle()
        else:
            if vis:
                annot.set_visible(False)
                fig.canvas.draw_idle()

fig.canvas.mpl_connect("motion_notify_event", hover)
plt.xlabel('all lines')
plt.ylabel('last 4 lines')
#print(sc.get_offsets(), "d")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="967">

# %%
def find_stanza(beginning,k=6):
    return [p.split("\n")[-k:] for p in stanzas if beginning.lower() in p.lower()]
find_stanza("proving their smartness")
# Out:
# [['Proving their smartness by their uniform,',
#   'proving their toughness by their uniform,',
#   "how often more calls wanted their die's supp.",
#   'Be worthy, and their ego is withwb.',
#   'For not self, but premier self, they achieved.',
#   'From latest copies, they admit defeat']]

# %% [markdown]
# ## 1 rand 7 gpt

# %%
data = open("../saved_objects/local_generated_stanzas/1rand_7g.txt").read()
scores = [[float(y) for y in x.split("[")[1].split("]")[0].split(",")] for x in data.split("1,7,")[1:]]
scores
# Out:
# [[5.543246269226074,
#   6.459848880767822,
#   6.055202007293701,
#   7.041181564331055,
#   7.584497928619385,
#   8.754639625549316,
#   8.942940711975098,
#   8.430963516235352],
#  [5.922362327575684,
#   7.649196624755859,
#   9.960135459899902,
#   6.094566822052002,
#   5.956660270690918,
#   7.542591094970703,
#   7.693263053894043,
#   8.819429397583008],
#  [5.228420734405518,
#   5.079268932342529,
#   9.423785209655762,
#   8.723094940185547,
#   6.538031578063965,
#   6.595355987548828,
#   6.9715986251831055,
#   9.216384887695312],
#  [5.794695854187012,
#   6.8819146156311035,
#   6.992441654205322,
#   7.47247314453125,
#   6.380641937255859,
#   9.1715087890625,
#   9.34582805633545,
#   6.933216094970703],
#  [5.94837760925293,
#   7.843466758728027,
#   8.102413177490234,
#   8.145746231079102,
#   8.342325210571289,
#   7.612734317779541,
#   7.1966872215271,
#   8.996211051940918],
#  [5.6305694580078125,
#   8.23283863067627,
#   6.581680774688721,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("mean score of each line")
plt.xlabel("index")
plt.ylabel("score")
for i in range(8):
    plt.scatter(i, np.mean([s[i] for s in scores]))

# %% [markdown]
# # 01/07

# %%
couplets = pickle.load(open("../saved_objects/couplets.p", "rb"))
couplets
# Out:
# [('expressly when his riddance do resume, what overwhelming power is his frown?',
#   [5.964007377624512, 7.42024564743042, 6.0250139236450195]),
#  ('die is sufficed, his ruffled hart, fair of; his funky devil must be stuffed with him.',
#   [5.166777610778809, 6.975750923156738, 5.349009990692139]),
#  ('but if he lays apply him to deduce, and put his word good when he says therein.',
#   [5.6132025718688965, 5.977459907531738, 5.094642162322998]),
#  ("proving a balance where connexions thump, and give good chances in his future'life.",
#   [5.99989128112793, 6.494480609893799, 6.103638648986816]),
#  ("now slaps the bill that should be another, how lovely more calls added his self'side.",
#   [5.751443862915039, 8.644634246826172, 7.016027450561523]),
#  ('die is unhinged, his sanguine fang, worth of; behaves the horror of his counterpart.',
#   [5.0824737548828125, 5.274219989776611, 5.359340667724609]),
# ...

# %%
scores = np.array([s[1] for s in couplets])
scores
# Out:
# array([[5.96400738, 7.42024565, 6.02501392],
#        [5.16677761, 6.97575092, 5.34900999],
#        [5.61320257, 5.97745991, 5.09464216],
#        [5.99989128, 6.49448061, 6.10363865],
#        [5.75144386, 8.64463425, 7.01602745],
#        [5.08247375, 5.27421999, 5.35934067],
#        [5.86026096, 8.80885601, 6.01134729],
#        [5.70987797, 6.38372707, 5.58186436],
#        [5.95464087, 7.61081696, 6.25907373],
#        [5.71009779, 5.51956415, 5.71581364],
#        [5.49085855, 4.59969616, 5.42523003],
#        [5.92834568, 7.19149637, 6.24651909],
#        [5.78734875, 6.83080339, 5.63653135],
#        [5.86904144, 6.46087599, 6.14662361],
#        [5.21412706, 4.31360054, 4.69715548],
#        [5.98481369, 5.40669727, 5.79750872],
#        [5.48842096, 6.71577644, 5.67030191],
#        [5.54301882, 7.95254898, 6.50011206],
#        [5.66070127, 6.13368988, 5.19798899],
#        [5.58162212, 6.1796751 , 5.65656948],
#        [5.7998929 , 5.65992546, 4.22286081],
# ...

# %%
plt.scatter(scores[:,1], scores[:,2])

# %%
plt.scatter(scores[:,0], scores[:,2])

# %%
def find(start):
    return [c[0] for c in couplets if start in c[0]]

# %%
np.mean(scores[:,2])
# Out:
# 5.704278464317322

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

x = scores[:,1] #x is second line
y = scores[:,2] #y is whole thing
names = np.array([s[0] for s in couplets])
c = scores[:,0] #c is first line

#norm = plt.Normalize(1,4)
cmap = plt.cm.RdYlGn

fig,ax = plt.subplots()
sc = plt.scatter(x,y,c=c, s=100, cmap=cmap)#, norm=norm)
plt.xlabel('second line')
plt.ylabel('whole couplet')
annot = ax.annotate("", xy=(0,0), xytext=(20,20),textcoords="offset points",
                    bbox=dict(boxstyle="round", fc="w"),
                    arrowprops=dict(arrowstyle="->"))
annot.set_visible(False)

def update_annot(ind):

    pos = sc.get_offsets()[ind["ind"][0]]
    print(pos)
    print(sc.get_offsets())
    annot.xy = pos
    text = "{}".format(" ".join([names[n] for n in ind["ind"]]))
    annot.set_text(text)
    annot.get_bbox_patch().set_facecolor(cmap(c[ind["ind"][0]]))
    annot.get_bbox_patch().set_alpha(1)


def hover(event):
    vis = annot.get_visible()
    if event.inaxes == ax:
        cont, ind = sc.contains(event)
        if cont:
            update_annot(ind)
            annot.set_visible(True)
            fig.canvas.draw_idle()
        else:
            if vis:
                annot.set_visible(False)
                fig.canvas.draw_idle()

fig.canvas.mpl_connect("motion_notify_event", hover)
plt.xlabel('second template loss')
plt.ylabel('whole line loss')
#print(sc.get_offsets(), "d")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
find("but if he")
# Out:
# ['but if he lays apply him to deduce, and put his word good when he says therein.',
#  'but if he jerks engulf him to caress, what interested feeling pulls his face?',
#  'but if he claps rejoin him to affix, and also swinging to the quarter horse.',
#  'but if he jams enclose him to berserk, proving his nature by his attitude.',
#  'but if he lasts permit him to report, a little captive knight in arms of ten.',
#  'but if he bleeds pervade him to subject, whose own account it probably presents.',
#  "but if he swims support him to prevail, and take good measures in his prison 'cross.",
#  "but if he raves consign him to today, not put the wooden 'Indiana gen.",
#  'but if he raps compute him to bernard, his latter title must be hanged with him.',
#  'but if he drips inflate him to digress, and that effect which actually is present.',
#  "but if he skates recast him to latrine, then stood the terror'explanation spread.",
# ...

# %% [markdown]
# ## 4-line stanzas

# %%
stanzas = [('his locust bloom might nip his handiwork\n is back the local council of his home.\n proving a pleasing where conditionseyed,\n click, be only, and his family is with him.',
  [6.002049922943115, 4.730053424835205]),
 ('proving a mixture where misfortunes lift,\n where all the help of his concerned calls get.\n for eating tender with himself alone,\n for not warm, but Premier warm, he forgot.',
  [6.026474475860596, 6.135856628417969]),
 ("upon herself, her boarder's mackintosh\n interest if she could traverse this deep frost of ice.\n proving a master where mechanics wing,\n will shine the children to the pretty pale.",
  [6.179790019989014, 6.451138019561768]),
 ("to flit the craig's sap by the hurst and shriek\n praise if we could carry this fair flood of blood.\n upon us, our slaying's RX\n homicide which started martyr parallels to have?",
  [6.938598155975342, 9.06710147857666]),
 ("upon himself, his jacket's guillotine\n butterfly what elevated order is his script?\n project's premier is welcome but does332,\n is stop, proving his future by his resume.",
  [6.925113677978516, 6.498795986175537]),
 ("to snare the team's look by the seams and lock\n grip the very thought where every frame has one.\n Ideal subjects would probably unlock\n or who she has so much to get the line.",
  [6.272449016571045, 5.251569747924805]),
 ("upon himself, his lamer's libertine\n counterpart what motivated whisky is his drive?\n but as the author should by guilt Cross,\n where all the prop of his bourgeois calls have.",
  [7.076953411102295, 6.859357833862305]),
 ('and coursing nymphs, they plays to those that trot\n those waters that with many fish were be.\n so long a time of plains, yet fit not rot\n where all the feast of their excess calls do.',
  [6.114834785461426, 6.68516731262207]),
 ("upon himself, his watchman's telescope\n telescope which mounted staring executes to form?\n Achieve the task or shrink this former chirop\nesthetic universe, whose wounds he has?",
  [7.595456123352051, 6.563279151916504]),
 ('directly when their pewter do react,\n is back the vital factor of their mode.\n the Catholic conscience Added them to paint\n oft in a free ideal shall they be blessed.',
  [6.556216716766357, 5.763764381408691]),
 ('unkempt rejects would heretofore adorn\n proving due, you is to those that are nick.\n but if you loves begin you to answ,\n proving fair, you is to those that are nick.',
  [5.217341423034668, 6.0200395584106445]),
 ("upon us, our chuckle's eskimos\n Scholarship oft in a Great Award shall we be paid.\n our captive day might work our came\n and purge our life deep when we is awake.",
  [6.379950523376465, 7.293119430541992]),
 ("upon yourself, your respite's chevalier\n gratitude to mortal question and proving you there.\n this walk to pass so passed when you did dear\n now how, when thinking is you, to be gone?",
  [6.044853210449219, 5.418512344360352]),
 ("upon myself, my flavor's mistletoe\n library and smell my bed good when i gets enough.\n Sometimes shall i be as exists be stunning,\n and bring good wishes in my presence's sweet.",
  [6.35971212387085, 6.63299560546875]),
 ("to note the quail's doth by the dune and tie\n lure a kindred pigeon bet in scraps of bread.\n of their nature to pass Rates,\n so how, when letter is them, to be made?",
  [6.331584453582764, 5.334158897399902]),
 ('but she eluded to her doodle eats\n for not look, but Premier look, she replied.\n look is required, her ardent tale, deep/,;\n of; and useful ink is part in staggering.',
  [6.933636665344238, 7.739595890045166]),
 ("upon us, our irksome's ridicule\n furthermore not dropped the instant's celebration borne.\n State. Exactly when our bias do Oilers,\n to rebel public and proving us there.",
  [7.418044567108154, 8.35277271270752]),
 ("and cloying brine, she pats to those that sign\n how truly more hers followed her self's mis.\n Stead. of her progress to vent overdue,\n Just how, when angle is her, to be sent?",
  [6.656562328338623, 6.120068073272705]),
 ('the pampered hissing hallowed him to munch\n or who he is so dear to fall the imp.\n Not is the pace that should beathed,\n another, for not die, but premier die, he approached.',
  [5.982353687286377, 6.418965816497803]),
 ("upon himself, his sojourn's coexist\n disappear which singled nature disappears to make?\n the mighty alter given him toontent\n draw and lift bright crystals in his plastic's stall.",
  [7.136852741241455, 6.945227146148682]),
 ('profoundly when your lizzie do repress,\n to lucid spirit and proving you there.\n proving a father where ideas play,\n if you could notice this good man of mind.',
  [6.119863510131836, 5.756105422973633]),
 ("upon myself, my trimming's marigold\n afternoon shall go my way and go my slow career.\n the other texture started me to rating\n will burn a second one of mine been rank.",
  [6.579357147216797, 6.80704402923584]),
 ("upon myself, my lion's taciturn\n attitude will change a little bit of red been soil.\n my leg's warm underneath so was on mystery\n too a little Super cut in parts of death.",
  [6.66532039642334, 6.801787376403809]),
 ('so plaid a riche of shrugs, yet yearn yet gnaw\n and skinny seedis wealth in staggering.\n staggering. so much a cloud of stars, yet do not draw\n and newly raging to the roaring sound.',
  [6.096386432647705, 7.355851173400879]),
 ("but he acknowledged to his loyal furs\n and never going to the city hall.\nLook went with Light and Purple knights quite Merge\n how quickly more calls headed his look's trail.",
  [6.9872636795043945, 8.067838668823242]),
 ('but he reverted to his whooping woes\n was an all daily talk and former vice.\n for very hanging chin is channel Pradesh,\n will pay the viewers to the very last.',
  [6.733066558837891, 5.274285316467285]),
 ('for gawking oneness with himself abstruse,\n if he could argue this self pre of self.\n Reply the kind or Make this private die\n oft in a short arcade might he be called.',
  [6.494321346282959, 6.290698528289795]),
 ('concisely when your gurney do contrive,\n oft in a few minute shall you be got.\n from shortest methods, you cannot escape\n sarcastic ridicule, whose bites you keeps?',
  [6.267797470092773, 7.066703796386719]),
 ('but if they links disguise them to monsieur,\n for where is they so near they shalt fair pass?\n for even having cut is faster on,\n where all the truth of their decree calls fit.',
  [6.339980602264404, 6.405857086181641]),
 ("but if you bites alight you to aghast,\n will do the others to the belly tight.\n to drill the skull's look by the caul and turn\n round or who you is so tight to do the top.",
  [5.722784996032715, 5.8445210456848145]),
 ('and munching drab, they grins to those that wish\n enduring gratitude, whose lives they has?\n so they through circles of good times shallァ,\n oust, and that disease which always Hunts torment.',
  [6.709218978881836, 6.862821102142334]),
 ("upon yourself, your lizzy's porcupine\n underneath the newly formed where every sound is heard.\n to wash the word's warm by the taste and ROM\n LOVE unravel underneath, whose cleans you breaks?",
  [6.90054988861084, 8.729020118713379]),
 ('now sprays the verb that should be another,\n shall be their fate and bless their stained career.\n but as the bullet should by law receive,\n for not self, but Premier Sap, they received.',
  [6.2447357177734375, 7.144829750061035]),
 ("upon herself, her fresco's chevalier\n Uniform a steady challenge was in stores of pride.\n Detail the che or cross this Irish peer\n oft in a fur costume might she be styled.",
  [6.793004512786865, 6.380220413208008]),
 ('and fanning fat, we stings to those that brag\n and that deny which also is present.\n of our deceit to give itiner,\n if we could comfort this fair wife of ours.',
  [5.936617374420166, 5.111330032348633]),
 ("upon us, our pinker's promenade\n intersect be other, and our yellow stars with us.\n for surely longing kind is singing Mitt,\n provides the music of our solitude.",
  [6.226872444152832, 4.966492176055908]),
 ("upon us, our sceptre's lullaby\n everything to other fleeting and proving us there.\n for being mindful with ourselves Gam,\n how often more hers darkened our Self's sleep.",
  [6.825552463531494, 8.13642692565918]),
 ("upon yourself, your mooney's apropos\n anymore and really searching to the person Wolf.\n Beware the pos or crank this weary tho\n and that degree which nightly lies consent.",
  [7.306541442871094, 8.677602767944336]),
 ("upon us, our vendor's rectitude\n advocate proving deep, we is to those that are dry.\n proving a poison where combatants Charter,\n or who we needs so much to be the law.",
  [6.492641448974609, 5.043681621551514]),
 ("upon himself, his chicken's sobriquet\n overcame whose real mistake it probably deserves.\n from closest users, he become essay\n proving his acting by his dialogue.",
  [7.090803623199463, 5.374129295349121]),
 ('but if we spurs revive us to reproach,\n whose good estate it probably exceeds.\n so we through manners of good works shall be,\n for where is we so young we is worth work?',
  [5.99542760848999, 6.742062568664551]),
 ('but if she shrieks refine her to astride,\n proving her useless by her attitude.\n Perhaps shall she be as regards befit,\n STEM, proving good, she is to those that are good.',
  [5.630208969116211, 5.226747989654541]),
 ("upon yourself, your privy's crocodile\n underneath will have the features to the fully grown.\n this work to get quite used when you were-----\n Freddie Freeman, and your inner pains with you.",
  [6.2897539138793945, 5.715151786804199]),
 ('so lank a maine of nymphs, yet don yet dive\n die further, and your lady sits with you.\n Then comes the day that should be shift,\n whose light spring it probably reminds.',
  [5.848377227783203, 8.66129207611084]),
 ('deprive the bloom or warps this flighty waltz\n and muddy riff is one in staggering.\n so much a trip of guys, yet say soXP\n link whose skin response it probably maintains.',
  [6.962350845336914, 7.7643208503723145]),
 ("to quench the swirl's die by the shard and slide\n clean is back the normal sliding of their teeth.\n the only difference pictured them to hide\n reveals the pattern of their disappear.",
  [6.270511627197266, 5.476684093475342]),
 ("proving a noodle where misfortunes sue,\n how often more hers challenged their self's quest.\n Nay. Together when their sever do recount,\n for not self, but Premier self, they conceived.",
  [6.340243816375732, 6.558258056640625]),
 ("for mopping wheezing with myself abreast,\n yet straight the cellar's ventilation fan.\n Bid. i says, believes the full self some reply\n and folly weeping to the morning time.",
  [6.752694606781006, 7.480629920959473]),
 ('and slouching psalm, you smokes to those that lay\n yourselves the trembling of your desolate.\n but if you shows observe you to display,\n proving your judgment by your company.',
  [6.143457889556885, 5.207948207855225]),
 ("that grisly patten's calms might cruelly swoon\n seek your present balance must be found with you.\n your present fin might stir your afternoon\n be careful, and your balance is with you.",
  [5.512782573699951, 4.272299766540527]),
 ('but if she haunts compare her to assent,\n and that profound which never rests prevail.\n Then singing came where all her own hers lay,\n proving her mistress by her attitude.',
  [6.181237697601318, 5.30210542678833]),
 ("proving a cranky where temptations ooze,\n will foil a second class of mal been wheel.\n our stout's self estimate so learned on long\n as so how, when something lays us, to be sworn?",
  [6.502655506134033, 6.285652160644531]),
 ("to jolt the jugs's doth by the breeze and irk\n freeze how quickly more calls sounded our self's loud.\n Har. for reckoning tally with us b,\n and that concern which gently feels express.",
  [7.110492706298828, 8.372049331665039]),
 ("the scruffy gurney fisted me to know\n how poorly more calls suffered my warm's look.\n Ter. forget the name or call this proper tho\n replies the patient of my unaware.",
  [7.069991588592529, 6.897231101989746]),
 ("correct the garb or groom this dainty meek\n shall be my bride and set my seal beside.\n so brave a bride of fits, yet do not speak\n and fall self forwards in my father's yard.",
  [5.35059928894043, 6.5165276527404785]),
 ("upon herself, her tenor's diocese\n patriarch determined anything, whose means she has?\n complaint's demand has nothing but calls 1951,\n set, proving her woman by her attitude.",
  [6.819230079650879, 6.28397798538208]),
 ("to rouse the smith's self by the mouse and see\n tend and kindly liking to the tempering.\n Touch. for piercing thousand with myself 179,\n for not look, but frontier self, i became.",
  [6.775631904602051, 7.1161603927612305]),
 ("but they acquired to their gothic loaves\n and have their rule deep when they grips around.\n upon himself, their preacher'scountry\n's atmosphere for where does they so black they looks deep whit?",
  [6.937185287475586, 8.487998962402344]),
 ("upon herself, her spasm's citadel\n underneath where all the snow of her surreal HersSet.\nLook. so she through layers of warm bonds shall CR,\n and certain death is mine in staggering.",
  [7.093291282653809, 7.751392841339111]),
 ('entail the fit or shave this irksome snooze\n if you could manage this good use of time.\n but you succeeded to your little screws\n and post yourselfself when you sleeps asleep.',
  [5.827373027801514, 8.095333099365234]),
 ('but as the mangle should by shawl confine,\n so how, when sever tracks him, to be drawn?\n Complete commands would probably require\n or who he is so much to lose the prize.',
  [5.98347282409668, 5.007399082183838]),
 ('but if you hounds endure you to decease,\n be content, and your ally is with you.\n within your dead die, your recruits reside\n whose swift decay it probably preserves.',
  [5.8570380210876465, 7.936234951019287]),
 ('then rings the one that should be another,\n shall cease his course and give his light wherein.\n So is the doom that should be another,\n did an allready mean and dismal one.',
  [5.576954364776611, 6.794656276702881]),
 ("upon myself, my guileless's lafayette\n dialogue reveals the difference of my attitude.\n but if i does become me to regret,\n and know my self worth when i leaves alone.",
  [5.684897422790527, 6.130461692810059]),
 ("upon herself, her silence's faraway\n gratitude oft in a sweet disguise might she be sur.\n but as the singing should by night convey,\n will lose the minutes to the lowly sleep.",
  [6.31137228012085, 6.168764591217041]),
 ("doth is embossed, my sanguine prowl, due of;\n how ever more calls wanted my self's sake.\n Blast. but if i sets avoid me to consult,\n look unto, and my counsel shalt with me.",
  [6.374669075012207, 5.570718765258789]),
 ("upon herself, her gawking's statuette\n miniature oft in a high estate should she be asked.\n Then being made where all her fair calls set,\n where all the night of her above hers lay.",
  [5.878535270690918, 5.963642597198486]),
 ('and wafting dutch, we thinks to those that trudge\n and waste our breath deep when we lands again.\n proving a service where releases judge,\n is back the future mountain of our soul.',
  [6.323056697845459, 6.430508136749268]),
 ("upon myself, my softness's honeycomb\n attitude what satisfying killing feels my mud?\n but if i shalt describe me to vend,\n those moments that with bitter lot was seek.",
  [7.165034770965576, 8.069684028625488]),
 ("but if she warms dispense her to riposte,\n to utter stomach and proving her there.\n Again shall she be as objects bewitch,\n bless, and blame good women in her presence's space.",
  [5.804126262664795, 6.154384136199951]),
 ('from farthest comforts, you contrive beseech\n proving your content by your appetite.\n Alone shall you be as towards bereach,\n pas, your neighbour sleeping must be found with you.',
  [6.004307270050049, 5.854718208312988]),
 ("sap is outshone, our shapeless earth, fair of;\n will give the people to the lovely dark.\n this drink to love so named when we were sad\n now hath the power's inspiration drank.",
  [6.008413314819336, 6.9151611328125]),
 ("yet lurks the troll that should be another,\n those stories that with other help were drag.\n Beware's progress has reason but has shun,\n look, for where is she so long she shows selfmeat?",
  [6.616154670715332, 6.523866176605225]),
 ("upon yourself, their wither's catacombs\n underneath those towers that with rusty claws were build.\n Look is announced, their dire fate, deep presentation;\n if they could measure this good day of praise.",
  [6.197290420532227, 5.692808628082275]),
 ("upon yourself, your doubting's lancelot\n suicide if you could ruin this good thing of mine.\n your stuff's worth everything so put on Devils\n back remains the singer of your merchandise.",
  [6.160122871398926, 6.787495136260986]),
 ("succinctly when your squalor do endorse,\n a total absence made in Gods of War.\n Release's career with Acid was perfect,\n perfect, to equal Triumph and proving you there.",
  [6.233975410461426, 7.397344589233398]),
 ("upon yourself, your talent's epithet\n everyone and press worth millions in your movie's box.\n Play. of your career to die scripts,\n where all the game of your above calls go.",
  [6.179791450500488, 6.183613300323486]),
 ("and tainting clown, he lends to those that mow\n beside unmanned and shrouded every where.\n Beware the sway or sway this bitter snow\n too hath the power's alteration mac.",
  [7.05157470703125, 8.30805778503418]),
 ("upon us, our tribute's tambourine\n underground and woven hand has freed in staggering.\n but we depended to our shamelessVPN\n brands what calculated meaning is our spring?",
  [7.383975505828857, 8.194905281066895]),
 ("the arid isthmus pillaged me to fume\n where all the moist of my present calls fit.\n Look is betrayed, my inward eye, dueaddin;\n of; then spoke the evil's inspiration forth.",
  [6.599437713623047, 6.706228733062744]),
 ("upon us, our backing's handiwork\n complicate and add our share due when we makes enough.\n upon us, our backing's paperwork\n envelope be hidden, and our trader proves with us.",
  [5.825725078582764, 6.471055507659912]),
 ('our rumble round might plow our harpsichord\n proving our preference by our appetite.\n proving a preference where ideasSong,\n want, will go the trials to the very last.',
  [6.367094039916992, 4.573073863983154]),
 ("to paint the shire's look by the croak and prance\n make dramatic dialogue, whose stars we has?\n but if we goes unveil us to romance,\n and also acting to the reader kind.",
  [6.331665992736816, 6.8370842933654785]),
 ('and baiting naught, he swims to those that drown\n for not die, but Premier die, he supposed.\n for seeing pity with himself around,\n those divers that with humble bread did drown.',
  [5.918747901916504, 8.997565269470215]),
 ("upon yourself, your sorrow's uppermost\n attitude and utter self is DON in staggering.\n your hollow tail might be your African\n and that constraint which only keeps uphold.",
  [7.334610462188721, 8.166857719421387]),
 ('when other borrows shall outrun their newts,\n and beg their bite good when they is around.\n within their net self, their remains repeat\n which banished season indicates to be?',
  [6.647493362426758, 9.350516319274902]),
 ("upon us, our grandest's coronet\n butterfly sufficient gratitude, whose speaks we knows?\n so glad a day of sorts, yet live now let\n will be a little kind of mine been self.",
  [6.769037246704102, 6.094717025756836]),
 ('yet roasts the draught that should warm another,\n will end the evils to the later poor.\n Look hast with care and backward eyes quite caught\n shall cease my song and cease my sigh amongst.',
  [6.377405166625977, 6.260141849517822]),
 ("upon myself, my writing's unafraid\n anymore how badly more calls ruined my self's day.\n Try. from Greatest Movies, i agree afraid\n if i could rally this self one ofrue.",
  [7.095067501068115, 7.686818599700928]),
 ("upon herself, her chancellor's whisperer\n dialect distinguished anyone, whose looks she has?\n to sit within her self due vitalios,\n towards, not how, when volume is her, to be found?",
  [6.613564968109131, 5.246462821960449]),
 ("forever when your preaching do atone,\n and pleasing speech is milk in staggering.\n Divine's response with running went perfect,\n perfect, for not look, but Premier die, you received.",
  [6.7278008460998535, 6.569029331207275]),
 ('die is distilled, his tepid ache, worth of;\n was an all quiet rest and idle dress.\n Especially when his sister do abhor,\n shall go his horse and stay his ear anew.',
  [5.940704345703125, 6.0647430419921875]),
 ("upon herself, her hummer's disrepute\n yesterday shall be her name and rank her white estate.\n Look saw with home and private eyes quite Lav\n proving her glory by her disregard.",
  [6.66656494140625, 6.0053229331970215]),
 ("upon yourself, your guileless's oversight\n paragraph and that bizarre which even seems correct.\n Perhaps shall you look as yourselves lookaimon,\n craft, and fellowman isday in staggering.",
  [7.049575328826904, 7.355756759643555]),
 ("upon myself, my moment's disarray\n overcame and that relief which only comes release.\n for missing nothing with myself away,\n proving due, iis to those that are near.",
  [6.352612018585205, 5.647748947143555]),
 ("upon myself, my steamer's reservoir\n reservoir and that ferment which always has retreat.\n proving a zero where conditions resulted,\n what continental region is my taste?",
  [7.094211101531982, 7.152495861053467]),
 ("upon ourselves, our bailiff's overcoat\n anything be common, and our mayor is with us.\n Now is the time that should be wear,\n our solemn dinner must be brought with us.",
  [4.980555057525635, 5.571691989898682]),
 ("but we resembled to our sumptuous flasks\n how brightly more Hers suited ourself's heart.\n's speech. our Danish pro might serve ouriliation\n anything oft in a harsh disdain Should we be hurt.",
  [7.339728832244873, 7.569812774658203]),
 ('the oxen phalanx humbled her to search\n for not look, but Premier look, she betrayed.\n but as the struggle should by prim retaliate,\n whose cheek cannot it otherwise resists.',
  [6.8432722091674805, 8.902363777160645]),
 ('but if she steers distort her to genteel,\n and that address which never flows succeed.\n this laugh to flow not used when she were blind\n if she could stumble this self tongue of wine.',
  [6.404126167297363, 7.15004301071167])]

# %%
stanza_scores = np.array([s[1] for s in stanzas])

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

x = stanza_scores[:,0] #x is whole
y = stanza_scores[:,1] #y is last line
names = np.array([s[0] for s in stanzas])
#c = scores[:,0] #c is first line

#norm = plt.Normalize(1,4)
cmap = plt.cm.RdYlGn

fig,ax = plt.subplots()
sc = plt.scatter(x,y,s=100, cmap=cmap)#, norm=norm)
plt.xlabel('whole stanza')
plt.ylabel('last line')
annot = ax.annotate("", xy=(0,0), xytext=(20,20),textcoords="offset points",
                    bbox=dict(boxstyle="round", fc="w"),
                    arrowprops=dict(arrowstyle="->"))
annot.set_visible(False)

def update_annot(ind):

    pos = sc.get_offsets()[ind["ind"][0]]
    print(pos)
    print(sc.get_offsets())
    annot.xy = pos
    text = "{}".format(" ".join([names[n] for n in ind["ind"]]))
    annot.set_text(text)
    annot.get_bbox_patch().set_facecolor(cmap(c[ind["ind"][0]]))
    annot.get_bbox_patch().set_alpha(1)


def hover(event):
    vis = annot.get_visible()
    if event.inaxes == ax:
        cont, ind = sc.contains(event)
        if cont:
            update_annot(ind)
            annot.set_visible(True)
            fig.canvas.draw_idle()
        else:
            if vis:
                annot.set_visible(False)
                fig.canvas.draw_idle()

fig.canvas.mpl_connect("motion_notify_event", hover)
#print(sc.get_offsets(), "d")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def find_stanza(start):
    return [c[0] for c in stanzas if start in c[0]]

# %%
find_stanza("upon ourselves, our bailiff")
# Out:
# ["upon ourselves, our bailiff's overcoat\n anything be common, and our mayor is with us.\n Now is the time that should be wear,\n our solemn dinner must be brought with us."]
